# %% [markdown]
# # **Homework 5 (Colab Version)**

# %%
# %pip install -U PySuperTuxKart

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# %cd /content/drive/MyDrive/EC418_final_project/
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/EC418_final_project

# %%
# !pip install imageio==2.4.1

# %% [markdown]
# # TuxKart gym

# %%
# !pwd
# Out:
# /content/drive/MyDrive/EC418_final_project

# %%
# !ls
# Out:
#  bundle.py	   grader    'Homework 5_files'   SuperTuxKart	 tuxkart-ai
#  environment.yml   homework   requirements.txt	  __temp__.mp4

# %%
# %cd /content/drive/MyDrive/EC418_final_project/tuxkart-ai
# Out:
# /content/drive/MyDrive/EC418_final_project/tuxkart-ai

# %%
# !apt-get install swig cmake libopenmpi-dev zlib1g-dev xvfb x11-utils ghostscript ffmpeg -qq #remove -qq for full output
# !pip install pyvirtualdisplay ghostscript

# %%
# !pip install stable_baselines3

# %%
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'

# %%
# Environmental flag to visualize in colab.
# %env ON_COLAB=1

# Hack for notebooks.
from importlib import reload
#from homework import utils; reload(utils)
from src import controller; reload(controller)

# %%
# %matplotlib inline
# !python tests.py
# Out:
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# src/env.py test successful

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from google.colab import output
path = '/content/tests11/'
images = os.listdir(path)
def last_7chars(x):
    return(x[-7:])

images = sorted(images, key = last_7chars)
fig1 = plt.figure()
for file in images:
  if (file.endswith(".png")):
    output.clear(wait=True)
    testim = plt.imread(path + file)  
    plt.imshow(testim)
    plt.pause(0.3)

# %%
# %reload_ext tensorboard
# %tensorboard --logdir . --reload_interval 1

# %%
# !python train-custom.py

# %%
# !python test_model_custom.py
# Out:
# tcmalloc: large alloc 1966080000 bytes == 0x7f5df6d00000 @  0x7f5fac3cb001 0x7f5fa963e22f 0x7f5fa969668b 0x7f5fa96974f7 0x7f5fa9739913 0x5aa114 0x49ced5 0x55e858 0x5d7cf1 0x49ca7c 0x55e858 0x5d7cf1 0x5d9487 0x586306 0x5d808f 0x560200 0x4fda1b 0x49caa1 0x55e858 0x5d7cf1 0x49ca7c 0x4fdff5 0x49caa1 0x55e571 0x55ef23 0x642140 0x6421be 0x644688 0x644c2c 0x6776be 0x677889
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# ...

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from google.colab import output
path = '/content/ppo_test/'
images = os.listdir(path)
def last_7chars(x):
    return(x[-7:])

images = sorted(images, key = last_7chars)
fig1 = plt.figure()
for file in images:
  if (file.endswith(".png")):
    output.clear(wait=True)
    testim = plt.imread(path + file)  
    plt.imshow(testim)
    plt.pause(0.3)
